# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
from datetime import datetime
import sys

def dailyCount(tws, verbose = True):
    '''
    input_file: data frame, which contains columns: user_id_str, created_at
    verobse: bool: print out some extra info 
    rtype:   data frame with three columns -- users_id_str, created_date, count
    '''
    
    tws = tws.loc[:,['user_id_str','created_at']]
    tws['created_at'] = pd.to_datetime(tws['created_at']).dt.date
    
    #loop through the file, count of tweets based on key (user_id, date)
    all_users = {}
    for i in range(len(tws)):
        (u,k) = tws.iloc[i]
        if u in all_users:
            if k in all_users[u]:
                all_users[u][k] += 1
            else:
                all_users[u][k] =1
        else:
            all_users[u] = {}
            all_users[u][k] = 1
            
    #convert dictionary to dataframe      
    all_users_df = None
    for u in all_users:
        aa = all_users[u]
        df = pd.DataFrame.from_dict(aa, orient='index')
        df['user_id_str'] =  u
        df['created_date'] = df.index
        df['count'] = df.iloc[:,0]
        df = df.loc[:,["user_id_str","created_date","count"]]
        all_users_df = pd.concat([all_users_df,df])           
        
    #output as csv file
    if verbose:
        print ("dataframe shape:", all_users_df.shape,
               "number of users:" + str(len(all_users_df.loc[:,'user_id_str'].unique())), 
               "number of tweets:" + str(sum(all_users_df.loc[:,'count'])))    
    return all_users_df    
def dailyCount_helper(files, i):
    start_time = datetime.now()
    f  = files[i]
    input_file = join("../../data/friends_info/edgelist_Feb27/timelines_csv_simplified/", f)
    tws = pd.read_csv(input_file, dtype =str, index_col = None) # no index
    #tws = tws.iloc[:1000]
    result = dailyCount(tws)
    result.to_csv("../../data/friends_info/edgelist_Feb27/timelines_csv_dailycounts/"+f, index = False, header=False) 
    #without header, index, easier to combine.
    print(files[i]+" is done.  time lapse: "+str(datetime.now() - start_time))
    
'''
if __name__ == '__main__':
    i = sys.argv[1]
    files = listdir("../../data/friends_info/edgelist_Feb27/timelines_csv_simplified/")
    files.sort()    
    dailyCount_helper(files, i)   
'''
# Out:
# '\nif __name__ == \'__main__\':\n    i = sys.argv[1]\n    files = listdir("../../data/friends_info/edgelist_Feb27/timelines_csv_simplified/")\n    files.sort()    \n    dailyCount_helper(files, i)   \n'

# %%
from joblib import Parallel, delayed
import multiprocessing
# what are your inputs, and what operation do you want to
# perform on each input. For example...

files = listdir("../../data/friends_info/edgelist_Feb27/timelines_csv_simplified/")
files.sort()
num_cores = multiprocessing.cpu_count()
results = Parallel(n_jobs=3) (delayed(dailyCount_helper)(files, i) for i in range(len(files)))
# Out:
# dataframe shape: (1148811, 3) number of users:3476 number of tweets:6598916
# t01_part3.csv is done.  time lapse: 0:14:23.670432
# dataframe shape: (1738252, 3) number of users:5088 number of tweets:9648925
# t01_part4.csv is done.  time lapse: 0:24:57.855429
# dataframe shape: (2836409, 3) number of users:6750 number of tweets:15250554
# t01_part2.csv is done.  time lapse: 0:42:20.720249
# dataframe shape: (3812705, 3) number of users:9123 number of tweets:21913328
# t01_part1.csv is done.  time lapse: 1:03:17.325535
# dataframe shape: (2300468, 3) number of users:5771 number of tweets:12087287
# t02_part2.csv is done.  time lapse: 0:30:09.380160
# dataframe shape: (1300582, 3) number of users:3612 number of tweets:6867563
# t02_part3.csv is done.  time lapse: 0:14:18.819836
# dataframe shape: (1872823, 3) number of users:5037 number of tweets:10112052
# t02_part4.csv is done.  time lapse: 0:26:58.150911
# dataframe shape: (4147442, 3) number of users:10093 number of tweets:21866483
# t02_part1.csv is done.  time lapse: 1:10:30.498488
# dataframe shape: (1305065, 3) number of users:3501 number of tweets:6685423
# t03_part3.csv is done.  time lapse: 0:15:38.900943
# dataframe shape: (2134901, 3) number of users:5249 number of tweets:10789573
# t03_part2.csv is done.  time lapse: 0:27:47.923114
# dataframe shape: (4263732, 3) number of users:10447 number of tweets:21747728
# t03_part1.csv is done.  time lapse: 1:08:14.142183
# dataframe shape: (1954354, 3) number of users:5175 number of tweets:10807796
# t03_part4.csv is done.  time lapse: 0:25:55.451322
# dataframe shape: (1119427, 3) number of users:3585 number of tweets:6626607
# t04_part3.csv is done.  time lapse: 0:14:33.141441
# dataframe shape: (1952510, 3) number of users:4824 number of tweets:9843273
# t04_part2.csv is done.  time lapse: 0:22:16.909103
# dataframe shape: (1503530, 3) number of users:5045 number of tweets:8954152
# t04_part4.csv is done.  time lapse: 0:23:22.010197
# dataframe shape: (4388482, 3) number of users:10742 number of tweets:21748345
# t04_part1.csv is done.  time lapse: 1:13:17.904764
# dataframe shape: (2015374, 3) number of users:5038 number of tweets:9919811
# t05_part2.csv is done.  time lapse: 0:24:51.913822
# dataframe shape: (1119591, 3) number of users:3696 number of tweets:6570629
# t05_part3.csv is done.  time lapse: 0:15:03.068163
# dataframe shape: (1545324, 3) number of users:4905 number of tweets:9049285
# t05_part4.csv is done.  time lapse: 0:21:13.050538
# dataframe shape: (4102329, 3) number of users:10103 number of tweets:20262220
# t05_part1.csv is done.  time lapse: 1:22:12.072862
# dataframe shape: (1880888, 3) number of users:4683 number of tweets:9099670
# t06_part2.csv is done.  time lapse: 0:23:28.392172
# dataframe shape: (1222218, 3) number of users:3380 number of tweets:6582446
# t06_part3.csv is done.  time lapse: 0:13:48.496739
# dataframe shape: (2174679, 3) number of users:5274 number of tweets:10647663
# t06_part4.csv is done.  time lapse: 0:28:26.704558
# dataframe shape: (4293160, 3) number of users:10834 number of tweets:21060113
# t06_part1.csv is done.  time lapse: 1:13:14.964801
# dataframe shape: (1417508, 3) number of users:3340 number of tweets:6771595
# t07_part3.csv is done.  time lapse: 0:15:57.515944
# dataframe shape: (1718039, 3) number of users:4391 number of tweets:8241529
# t07_part2.csv is done.  time lapse: 0:20:11.902951
# dataframe shape: (2212200, 3) number of users:5183 number of tweets:10771983
# t07_part4.csv is done.  time lapse: 0:26:58.868602
# dataframe shape: (1690952, 3) number of users:4285 number of tweets:8125542
# t08_part2.csv is done.  time lapse: 0:21:22.416205
# dataframe shape: (1260169, 3) number of users:3291 number of tweets:6491675
# t08_part3.csv is done.  time lapse: 0:15:17.873882
# dataframe shape: (4360149, 3) number of users:11021 number of tweets:20974752
# t08_part1.csv is done.  time lapse: 1:13:38.436394
# dataframe shape: (4354560, 3) number of users:10988 number of tweets:20938528
# t07_part1.csv is done.  time lapse: 1:59:25.167883
# dataframe shape: (1853720, 3) number of users:5261 number of tweets:9734571
# t08_part4.csv is done.  time lapse: 0:24:02.021892
# dataframe shape: (1634241, 3) number of users:4124 number of tweets:7643794
# t09_part2.csv is done.  time lapse: 0:16:56.619480
# dataframe shape: (1217576, 3) number of users:3581 number of tweets:6651780
# t09_part3.csv is done.  time lapse: 0:14:50.789522
# dataframe shape: (1878701, 3) number of users:4910 number of tweets:9636841
# t09_part4.csv is done.  time lapse: 0:21:37.606795
# dataframe shape: (1601626, 3) number of users:4106 number of tweets:7440517
# t10_part2.csv is done.  time lapse: 0:16:45.303632
# dataframe shape: (4360970, 3) number of users:11235 number of tweets:20954386
# dataframe shape: (1353684, 3) number of users:3229 number of tweets:6566056
# t10_part3.csv is done.  time lapse: 0:13:58.087670
# t09_part1.csv is done.  time lapse: 1:11:39.878457
# dataframe shape: (1390438, 3) number of users:3813 number of tweets:7313792
# t10_part4.csv is done.  time lapse: 0:15:35.811179
# dataframe shape: (4386511, 3) number of users:11175 number of tweets:20950629
# t10_part1.csv is done.  time lapse: 1:13:36.623906
# dataframe shape: (1521809, 3) number of users:3840 number of tweets:7001221
# t11_part2.csv is done.  time lapse: 0:15:43.379333
# dataframe shape: (1167312, 3) number of users:3844 number of tweets:6552371
# t11_part3.csv is done.  time lapse: 0:15:53.289401
# dataframe shape: (1477818, 3) number of users:4616 number of tweets:8003393
# t11_part4.csv is done.  time lapse: 0:17:41.584892
# dataframe shape: (1482317, 3) number of users:3811 number of tweets:6878922
# t12_part2.csv is done.  time lapse: 0:14:47.636758
# dataframe shape: (4464855, 3) number of users:11441 number of tweets:20953763
# t11_part1.csv is done.  time lapse: 1:13:46.889760
# dataframe shape: (1280222, 3) number of users:3221 number of tweets:6536675
# t12_part3.csv is done.  time lapse: 0:13:24.852194
# dataframe shape: (1658340, 3) number of users:5244 number of tweets:9159040
# t12_part4.csv is done.  time lapse: 0:24:14.279307
# dataframe shape: (266918, 3) number of users:693 number of tweets:1240502
# t13_part2.csv is done.  time lapse: 0:02:25.383285
# dataframe shape: (1120061, 3) number of users:4367 number of tweets:6355396
# t13_part3.csv is done.  time lapse: 0:16:04.977516
# dataframe shape: (4469257, 3) number of users:11476 number of tweets:21057513
# t12_part1.csv is done.  time lapse: 1:17:25.235943
# dataframe shape: (1146618, 3) number of users:3719 number of tweets:6212128
# t13_part4.csv is done.  time lapse: 0:13:49.937516
# dataframe shape: (1321975, 3) number of users:3377 number of tweets:6121241
# t14_part2.csv is done.  time lapse: 0:13:18.265072
# dataframe shape: (4459032, 3) number of users:11689 number of tweets:20740886
# t13_part1.csv is done.  time lapse: 1:06:45.456523
# dataframe shape: (1266308, 3) number of users:3563 number of tweets:6574065
# t14_part3.csv is done.  time lapse: 0:14:18.786709
# dataframe shape: (1520335, 3) number of users:4573 number of tweets:8430047
# t14_part4.csv is done.  time lapse: 0:18:10.454599
# dataframe shape: (4590344, 3) number of users:11885 number of tweets:20954589
# t14_part1.csv is done.  time lapse: 1:11:29.331625
